# %%
import pandas as pd
from collections import defaultdict
from intervaltree import IntervalTree
import ast

# %%
# ==========================================================
# STEP 1: Load Input Data
# ==========================================================

print("Loading CW data...")
cw_df = pd.read_excel('cw_cleaned.xlsx')

print("Loading Perform data...")
perform_df = pd.read_excel('perform_datetime.xlsx')

print("Loading Event data...")
event_df = pd.read_excel('event_interpolated.xlsx')

# Handle datetime columns 
cw_df['start'] = pd.to_datetime(cw_df['start'], errors='coerce').dt.tz_localize(None)
cw_df['end'] = pd.to_datetime(cw_df['end'], errors='coerce').dt.tz_localize(None)
perform_df['result_from'] = pd.to_datetime(perform_df['result_from'], errors='coerce').dt.tz_localize(None)
perform_df['result_to'] = pd.to_datetime(perform_df['result_to'], errors='coerce').dt.tz_localize(None)
event_df['occurred_at'] = pd.to_datetime(event_df['occurred_at'], format="ISO8601").dt.tz_localize(None)
# Out:
# Loading CW data...
# Loading Perform data...
# Loading Event data...

# %%
# ==========================================================
# STEP 2: Align and Filter Datasets Using Asset IDs
# ==========================================================
print("Filtering Necessary Rows from Perform and Event Data...")

# # Define the vehicle types to filter for
# vehicle_types = ['FL', 'ARC']  

# # Filter cw_df to include only rows with the specified vehicle types
# cw_df = cw_df[cw_df['vehicleType'].isin(vehicle_types)].copy()

# Convert string representation of list to actual list
perform_df['asset_ids'] = perform_df['asset_ids'].apply(ast.literal_eval)
# Extract the single string from the list (since there is only 1 item per row)
perform_df['asset_ids'] = perform_df['asset_ids'].apply(lambda x: x[0] if isinstance(x, list) else x)

# Create a dictionary mapping asset_name -> asset_ids
mapping_dict = dict(zip(perform_df['asset_name'], perform_df['asset_ids']))

# Map cw_df['truck'] using this dictionary to get perf_asset_ids
cw_df['perf_asset_ids'] = cw_df['truck'].map(mapping_dict)

# Extract unique perf_asset_ids values from cw_df (excluding NaNs)
valid_asset_ids = cw_df['perf_asset_ids'].dropna().unique()

# Filter perform_df where asset_ids are in valid_asset_ids
perform_df_filtered = perform_df[perform_df['asset_ids'].isin(valid_asset_ids)].copy()

# Filter event_df to include only events matching the asset IDs of interest
event_df = event_df[event_df['asset_id'].isin(valid_asset_ids)].copy()
# Out:
# Filtering Necessary Rows from Perform and Event Data...

# %%
# ==========================================================
# STEP 3: Group Perform columns For Overlap Calculation
# ==========================================================
print("\nGrouping Perform columns for overlap calculation...")

# Categorize into WEIGHTED_AVG_COLS, CATEGORICAL_COLS, and LINEAR_SCALE_COLS
WEIGHTED_AVG_COLS = [
    'total_rating', 'coasting_rating', 'acceleration_pedal_rating', 'braking_pedal_rating',
    'cruise_control_rating', 'overspeed_rating', 'harsh_acceleration_rating', 'harsh_braking_rating',
    'average_speed', 'average_rpm', 'fuel_efficiency', 'operating_conditions_score',
    'overspeed_percentage', 'kickdown_percentage', 'excessive_idling_rating',
    'ambient_temperature_min', 'ambient_temperature_max'
]

excluded_cols = set(WEIGHTED_AVG_COLS + ['result_from', 'result_to', 'asset_name', 'asset_ids'])

LINEAR_SCALE_COLS = []
CATEGORICAL_COLS = []

for col in perform_df.columns:
    if col in excluded_cols:
        continue  # skip weighted avg and excluded cols
    
    # Skip columns that are empty or all NaN
    if perform_df[col].dropna().empty:
        continue
    
    if pd.api.types.is_numeric_dtype(perform_df[col]):
        LINEAR_SCALE_COLS.append(col)
    else:
        CATEGORICAL_COLS.append(col)

# print("\nWEIGHTED_AVG_COLS:", WEIGHTED_AVG_COLS)
# print("\nLINEAR_SCALE_COLS:", LINEAR_SCALE_COLS)
# print("\nCATEGORICAL_COLS:", CATEGORICAL_COLS)
# Out:
# Grouping Perform columns for overlap calculation...

# %%
# ==========================================================
# STEP 4: Merge Perform data with CW data Using IntervalTree
# ==========================================================
print("Building IntervalTree from Performance data...")

perf_intervals = []
for idx, row in perform_df.iterrows():
    perf_intervals.append((
        row['result_from'].timestamp(),
        row['result_to'].timestamp(),
        idx
    ))

perf_tree = IntervalTree()
for start_ts, end_ts, idx in perf_intervals:
    perf_tree[start_ts:end_ts] = idx

print("Merging Performance data with CW data...")

# Define Overlap Time Calculation Function
def calculate_overlap(start1, end1, start2, end2):
    overlap_start = max(start1, start2)
    overlap_end = min(end1, end2)
    delta = overlap_end - overlap_start
    return delta if delta > pd.Timedelta(0) else pd.Timedelta(0)

# Define merge Function Using IntervalTree
def merge_tour_performance_data_intervaltree(cw_df, perf_df, perf_tree):
    merged_rows = []

    for _, segment in cw_df.iterrows():
        merged_row = segment.to_dict()

        linear_sums = {col: 0.0 for col in LINEAR_SCALE_COLS}
        weighted = {col: {'sum': 0.0, 'duration': 0.0} for col in WEIGHTED_AVG_COLS}
        categorical_values = defaultdict(set)

        seg_start_ts = segment['start'].timestamp()
        seg_end_ts = segment['end'].timestamp()

        overlapping_perf_intervals = perf_tree.overlap(seg_start_ts, seg_end_ts)

        for interval in overlapping_perf_intervals:
            perf_idx = interval.data
            perf = perf_df.loc[perf_idx]

            if perf['asset_name'] != segment['truck']:
                continue

            overlap_dur = calculate_overlap(segment['start'], segment['end'], perf['result_from'], perf['result_to'])
            if overlap_dur.total_seconds() <= 0:
                continue

            perf_dur = perf['result_to'] - perf['result_from']
            overlap_ratio = overlap_dur.total_seconds() / perf_dur.total_seconds()

            for col in LINEAR_SCALE_COLS:
                if pd.notna(perf[col]):
                    linear_sums[col] += perf[col] * overlap_ratio

            for col in WEIGHTED_AVG_COLS:
                if pd.notna(perf[col]):
                    weighted[col]['sum'] += perf[col] * overlap_dur.total_seconds()
                    weighted[col]['duration'] += overlap_dur.total_seconds()

            for col in CATEGORICAL_COLS:
                if pd.notna(perf[col]):
                    categorical_values[col].add(str(perf[col]))

        for col in LINEAR_SCALE_COLS:
            merged_row[f'perf_{col}'] = linear_sums[col] if linear_sums[col] != 0 else None

        for col in WEIGHTED_AVG_COLS:
            dur = weighted[col]['duration']
            merged_row[f'perf_{col}'] = weighted[col]['sum'] / dur if dur > 0 else None

        for col in CATEGORICAL_COLS:
            values = sorted(categorical_values[col])
            merged_row[f'perf_{col}'] = ', '.join(values) if values else None

        merged_rows.append(merged_row)

    return pd.DataFrame(merged_rows)

# Apply merge function
cw_perform_df = merge_tour_performance_data_intervaltree(cw_df, perform_df, perf_tree)
# Out:
# Building IntervalTree from Performance data...
# Merging Performance data with CW data...

# %%
# ==========================================================
# STEP 5: Merge with Event Data 
# ==========================================================

print("Merging Event data with CW-Perform data...")

event_df = event_df.add_prefix('event_')

# Sort both dataframes by datetime to use merge_asof
cw_perform_df = cw_perform_df.sort_values('start').reset_index(drop=True)
event_df = event_df.sort_values('event_occurred_at').reset_index(drop=True)


merged_parts = []

for idx, row in cw_perform_df.iterrows():
    mask = (
        (event_df['event_occurred_at'] >= row['start']) &
        (event_df['event_occurred_at'] <= row['end']) &
        (event_df['event_asset_id'] == row['perf_asset_ids'])
    )
    matching_events = event_df.loc[mask].copy()
    if not matching_events.empty:
        repeated_cw = pd.concat([row.to_frame().T]*len(matching_events), ignore_index=True)
        merged = pd.concat([repeated_cw.reset_index(drop=True), matching_events.reset_index(drop=True)], axis=1)
        merged_parts.append(merged)

cw_perform_event_df = pd.concat(merged_parts, ignore_index=True)
# Out:
# Merging Event data with CW-Perform data...

# %%
# ==========================================================
# STEP 7: Save Final Output
# ==========================================================
print("Saving final output...")

# Save the cleaned dataframe
output_file = 'cw_perform_event.xlsx'
cw_perform_event_df.to_excel(output_file, index=False)
# Out:
# Saving final output...
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKAWE9YC67NM1ZMQ1J3T0021&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKAVQXKB40EK1YFR73A50JEE&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKAW3BAP7K5M1VFHZ2VE1DJ5&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKAWSATSJ74A00BE3KC2012A&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKAX53ZS9EDK1ESJ3RA70BHV&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKAXH6W0Q1761WRZQFDD1AMB&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKAZS83QRS1P0G7P0Z6V1DP0&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKB05DQ33P8S1MWN86P71YB2&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKB0HG0F08DV0DYGV56J196B&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKAXWJVM4H5Z1KE5A7P30752&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKAY9HP746AW0HGB0N8P17YD&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKAYNMSVN0CB01MAZRG00DCR&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKAZ0VR8YK5Q1G0ZPZNY1Z0W&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKAZCGS3WSPP0FS8MFJ20808&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKB0XBDV2BPC0MYC68WQ1WAH&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKB1AD080PY00MWAACRH0QTC&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKB1QS8A2A061QB527DM050P&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKB24BE8B0390YWM7AKX1MMV&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKB2GCE04NQV06TTK5JB0GND&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKB2WJMYKZFY061XN79X0V3Z&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKB399HTFRBY1QYAX9CS0D45&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKB3NGEHTYPK0VVXKCJ906CZ&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKB42SZ1QA7H01HC239A0X8K&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKB4GM5GQ7BG1VPCWFPF1PAZ&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKB4VZPM3TQX02M1GVHK162D&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKB59M87ZHTC190YVRF90YY5&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKB5QZC73Q7Z0T1JY8S01K5G&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKB6A9FA5CWC1PYXB6N90PFG&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKB6XBC3PFCZ0RTBP6JY0BKG&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKB7HVMBT4A609CJ60BY1Q01&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKB89A43VXDP1KTNM08T0R5R&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKB9AZN6PG2N0549P4AV0BVZ&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKBAX5C3DD590313S3ZS0G6P&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKBCJ38GM8KZ02WFDCVB0P81&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKCV0RY6M2QX1DTW0TPM07MH&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKCVB3NMEMZX0ZVG8C940DJB&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKCVP4Q1TTJB0TE6X31A0K4P&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKCW1CY47WBP1B6DFF1H0SEG&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKCXTZTQJDDN0Y892Y4H16AN&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKCY6Y55TWF81RK3F3XW17TM&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKCYJC8WV88R1317VX8J10BT&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKCYXQK50EV90TGM2Q4714RJ&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKCZ8ZT2TSJ21X4EYFGF07M3&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKCZM32B268J05EM8NF40CDW&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKCZYN221YQ518YC6ZVE1CXW&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKD091FFK9RJ0RYFXM240S17&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKD0KDKEP0FR0V512EY10SE0&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKD0XMCAWXD10SPJNYGF0X4C&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKD18MSGX3J910JF38V91VWE&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKCWCKQQMEJK1MGR6SX90739&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKCWR026AX2Q1Q8AT00C0TA8&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKCX3J49RGHP120FSCHC1ZQ6&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKCXF9SZPR6H18QJJZHP1RJH&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKD1KFMP5B881PK8SJHD0Q2V&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKD1YDN56K0J11P62Z570MZM&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKD29KZKGX131BSETBN11EJJ&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKD2ND2CTZFB0M83RER41E1W&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKD2ZPDGDXBH0XHR98G20K1C&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKD3A0GB56WP1F2GNF0902W4&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKD3MF22FMCD0C1W27VJ07RD&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKD3YKARBEN40ZWJH8DK0E5V&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKD48ZDBZJC00C4JF9J91AH5&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKD4JJRC4H5P135NF0X00R2P&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKD4XQH2NW7M16WFS5WG0G81&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKD591NV1MG91RHVH0DQ1M04&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKD5KZM00VT216Q6MASP18QP&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKD5YYR2A0TV1YYMFN0M1AQW&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKD69JS332ZX1XFVGR3V0J8C&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKD6MAPJHBZ514TE96PW1YQC&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKD6Z3C41G7V1DMHY3X31MR5&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKD79ZZVDPJN1Q1D0W2F06FY&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKD7N9H884GK10EFZZ7J0W0T&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKD7ZYCVF8WS0286KB6H0C9T&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKD8DQDFACWW0T6M8C3M0MS9&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKDAB6ZVHEPG0X4Z0R6018WT&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKDASWEBFZEX0A85ZF810SSV&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKDB6E7J8W1T1GZMZ4J50536&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKD8WMAKMJRR1Z51Z1FT179X&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKD9ASGND2DB17E3W4270Y0W&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKD9TRJGQ4ET0FTG2KBP0YFF&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKDCNZX9YEEX15WB67FZ0KEP&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKDBJ9EPRS3D0V9QWRHV1EV8&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKDBYEQTVFNB10BCKR3S1H13&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKDEV3CV8V3B163WATAJ181Q&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKDF5J59PQZF0C1V0QK31D64&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKDFH2CDED8C1Y1Y59JW0K0F&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKDCAGZZ7DH91QT0B11100RG&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKDD17739P651VNYPV3T16HH&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKDDDAGHKFH31JCDFP3A1D4E&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKDDRYBCQJCT00AT0K9F1VYS&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKDE46FARMCY1WBMNYCQ06Y7&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKDEG8250NZF13ZJV08H1M4T&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKDFVK2T2B6215HYEYG909B5&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKDG698AA4YT1T6YNWSP1WET&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKDGGS2PPAS40HGP0N6V1FDW&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKDGW1AEWCTZ17STGS1Z08MQ&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKDH6XNBG6R40QA4WW211MK2&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKDHGSB05RCW07H35ZY91CWJ&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKDHVT3S2PNJ0A3C9P731JWA&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKDJ6XXCTQB51VE6TAFN0R1X&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKDJH9B910DT0QYF3VE00EPH&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKDJW7FSD36N0ZC6Q0CN1B8T&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKDK708TY55Y0QK8VSBE0AY4&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKDKHXXGV0EH1NKZA2K80TW6&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKDKWHCE86EW0ZN0X2X40QH3&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKDM74DRK08V1ZSTDFYF1QV4&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKDMJRAM8JVE0J55D7PX0H0W&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKDMYDXNJADC190S1J0C0CPN&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKDN9BWWAD2M1YZVAF121J45&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKDNNGD6092311T1Z5T70JWC&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKDP1K8RWKV00178X3S80DNV&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKDPDT1NNN1A1CT2R7R50J57&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKDPVR4TETZB00BP134W0683&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKDQCWA22FT611MNR0870ZPT&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKDQVZ0A3ZBT1Q8AN2MC1F4B&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKDRCEGE7EWA0R86HZQ51GND&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKDRZ6DNMXV50Y9S6K5F14RQ&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKDSJKA18QAY1Q1E872B1B46&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKDTFAWHJF5Z1REGN2GH0C02&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKDZPKV2AP0X1DMDFNQC1PDG&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKDWJG98J49D0RFR4SP41BQT&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JK561YQEK95G0Z0FBN4T0WA5&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JK56E1DCK6Z00ET7530H1NJ7&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JK56TJ304TSZ1YX1QD5E0ZVC&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JK575XQ6EP7P0Y59W3XA1AQ9&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JK57HMNMJN7Q1Z6SNGS20T04&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JK57X5AGZSB31ZTHM0GW0Y18&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JK5888AM8CF6177658Z40JVT&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JK58K6ZFG1YD0NCKHZBA0SM7&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JK58XPZHHK8H07HARR2T0W32&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JK5999NFD8ZJ1NKRED781E6P&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JK59M39EBRE016HABSA30AT7&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JK59ZMJSNWRY02FP43JT12RZ&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JK5AAHAH60ZX1CQJ5Q431STB&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JK5ANF44X8RR0D3QF8XV1E8N&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JK5B0RTGAGH10H3JGRQE0H17&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JK5BBSMDQHJV0S9493P11SM3&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JK5BR07Z8VVJ19D4AENV13FV&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JK5C4SJ2MY270TK5WP7P0KNK&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JK5CGFXBR1AN0X2EM9GY1THC&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JK5CW6DP8YZH0VVRY1XD0NN6&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JK5D7QE5HK2A1CSG8JY60YTV&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JK5DJZNKNXEC1ECDVA601F0Y&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JK5DZ9YG4J6R1NGHR74M0FTR&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JK5EB0BSRDVZ1VF399TD1P8V&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JK5ENQJTYJQN0EXEAVQ7149V&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JK5F1CYSE0RH18N19FA80M5P&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JK5FD1XJEMBN0G7EZ7S90H24&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JK5FS4T6AHG718GGXHBD0JBK&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JK5G41G71BN71GEGXSAC1GRF&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JK5GGG6EZF1N0TFVC1RR1F2A&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JK5GYKATB9C901KB8B6R051V&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JK5HCJN91XZW08541B2P162S&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JK5HW2SC80B41XCZ1TEC06S7&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JK5JGE50XMPM0ND46V0N0KJ1&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JK5JZPJPM3S8191TCRBB059A&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JK5KV9BD171C15MNQWR31X19&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JK5M8NY4MR1Z0DBFSNH90VAT&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JK5MM3W33QKG1XP841Y004HR&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JK5MY6NJAFD711JAECVF1G1B&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JK5N9S1N8KNV1MG73JHH03H0&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JK5NNW958X7K1JM66KPD0GWS&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JK5P08HYAPBT1TVT90WG1NSJ&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JK5KDJCJDH510AC5SMTM0FWW&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JK5PC95G3XEK0Z3ATF3D1T5Q&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JK5PQKCW7P4T1RX85ERX0244&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JK5Q32821XGK1C38XN641QR4&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JK5QGAPR73MA1KQ4RRDT0HNQ&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JK5SVMG4CH32182QQHKY01EN&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# ...
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JK8KMZNWKYWD03TTWA511HYH&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JK8MFPF65FJF1C4ECF4M10AQ&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JK8NE2YVN65S1VQKPP1N13QM&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JK8PJR07X2D71QZZNXJZ0JF9&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JK8RTPFAE24A0Z91YPWG1956&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JK8XK28YQMCP1QR6C4EW0NJM&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKA9J0N1JZ781WSTQJ8V1Y3J&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKA9Y9Y4C9V201R9TTWA1CZ4&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKAAAKPTTP3Q0Y3KKA461X2J&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKAAP8JQ5WK31FDYEPCV0ST1&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKAB20Q3VN0Y1VA78KV81EK1&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKABVFYCTNHV03HDAH3S0FZ2&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKAC7HXQ14TJ06H4M3XW0HX9&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKACK50CTJD30KJAQCZ914WS&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKACYWJNVZYW1SXBXZDA05F6&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKADAETNWNX81YG97J981BZE&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKADNPMNKZX90YS9BP7X1ZJW&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKABEYGXN5AC0ZQM6BTG01WP&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKAE1HBMMEKR1EN092R70V1B&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKAEBRE5H9VZ1GCP20SE1G1G&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKAEQHQGAC1N0Y5HFG94064P&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKAF2NE2B8N40YFQAN460VNW&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKAFEM1ECC8D0KHKP6M30C60&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKAFSH184J4J0XF9T0T61711&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKAG608514FA16483VKT0XEG&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKAGY6AJG64S17R5N1D410MK&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKAHAAXYG5KY1BE3BPHV1NRN&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKAHP7PECW7A1YKEK28S012D&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKAGJD3BJNTY18C7EK0N0TSS&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKAJ2RYDT3JE0KHP3QB01QZE&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKAJFVEJQM2K0WC92HSM0QH8&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKAJWAF3K7ZS0MT5T21K0A5M&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKAK62H1V7E11KZGV3TR1CA7&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKAKHBX5Q2VX1BZT594H0Z2K&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKAKX1H1QEQD0FYEAYWW1QJX&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKAM858X9DCC0CCVTBFN1T1R&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKAMM0X0WA6W1J9XVWA91E0P&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKAMZB04B7Z616GS3FV70E54&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKANA3T7QJVH1TEY2W541FTX&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKANNGNB1CM000S2XNDG005X&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKAP189HG65D069X2Q0H1753&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKAPD9PRE2M71C9JY7TM0Q0T&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKAPVC12KS9E0MWCQ8SH19WW&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKAQA1J02EY51AX2WWHN1Y07&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKAQRWNGXKY41Q326GM70KYV&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKAR8RTN11MD1FZF2C380PK7&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKARPYHWKMVR0V4Q67TM1HEV&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKAS3D0E159504757RR60ARH&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKASG0TH7Q3N12MVAX340662&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKASVVQ0PBHE1TNQVZT108HA&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKAT8G7C4FSS0HFTM9ED187R&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKATMYMJB5850NTHA0051A0E&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKAV0Z759H2S10H6433E1Z2C&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKAVCAP9AHAQ1T6FST6K12JJ&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKBEC16TGNNH1SC3CDB21ZXN&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
# /Users/tunkarlu/miniconda3/envs/myenv/lib/python3.12/site-packages/xlsxwriter/worksheet.py:1250: UserWarning: Ignoring URL 'https://feed.iot-events.rio.cloud/iot-events?after=01JKF86P5KC57C04KB47W812Q4&limit=1000' since it exceeds Excel's limit of 65,530 URLs per worksheet.
#   warn(
